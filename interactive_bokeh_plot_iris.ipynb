# %% [markdown]
# # Example Bokeh Application Embedded in Jupyter Notebook
#
# Hello, world / Iris data set example to illustrate embedding of Bokeh applications within a Jupyter notebook.
#
# Note that this example will only run with the latest version of [bokeh (version 0.12.5)](http://bokeh.pydata.org/en/latest/#).

# %%
import pandas as pd
import numpy as np
from bokeh.layouts import row, widgetbox
from bokeh.models import Select
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
from bokeh.application.handlers import FunctionHandler
from bokeh.application import Application

# %% [markdown]
# ## Load the Iris Data Set

# %%
iris_df = pd.read_csv("iris.data", 
    names=["Sepal Length", "Sepal Width", "Petal Length", "Petal Width", "Species"])
feature_names = iris_df.columns[0:-1].values.tolist()
iris_df.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Create Embedded Application

# %%
# Create the Document Application
def modify_doc(doc):
    
    # Create the main plot
    def create_figure():
        current_feature_name = feature_name.value
        p = figure(title=current_feature_name)
        hist, edges = np.histogram(iris_df[current_feature_name], density=True, bins=20)
        p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], fill_color='navy', line_color='#FFFFFF', alpha=0.5)
        p.y_range.start = 0
        p.legend.location = 'top_right'
        p.legend.background_fill_color = "#fefefe"
        p.xaxis.axis_label = current_feature_name
        p.yaxis.axis_label = 'Count'
        return p

    # Update the plot
    def update(attr, old, new):
        layout.children[1] = create_figure()
    
    # Controls
    feature_name = Select(title="Iris Feature:", options=feature_names, value=feature_names[0])
    feature_name.on_change('value', update)
    controls = widgetbox([feature_name], width=200)
    p = create_figure()
    layout = row(controls, p)
    doc.add_root(layout)

# Set up the Application 
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
# Create the Document
# Not strictly necessary, but helps w/ debugging
output_notebook()
doc = app.create_document()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8a70b088-1b98-4dda-aedf-831adaabae6c">Loading BokehJS ...</span>
#     </div>

# %%
# Show the application
# Make sure the URL matches your Jupyter instance
show(app, notebook_url="localhost:8888")
# Out:
# <script src="http://localhost:50684/autoload.js?bokeh-autoload-element=87ec0615-0693-4f70-bc74-f683f3a73657&bokeh-absolute-url=http://localhost:50684&resources=none" id="87ec0615-0693-4f70-bc74-f683f3a73657"></script>
